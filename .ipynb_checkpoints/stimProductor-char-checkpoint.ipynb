# %%
import pandas as pd
import random
import itertools  
# %pylab inline
path='D:\\Coding\\py\\py3\\experiment\\'
rawdata = pd.read_csv(path+'bichar.csv',encoding='gbk')
del rawdata['Unnamed: 0']
rawdata['match'] = rawdata[['c1_match','c2_match']].apply(lambda x: (eval(x[0]),eval(x[1])),axis=1)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
plot(sorted(blockTables[0].w_freq))

# %%
def randomInBlock(result,conditions,blockCount):
    blocks = [[] for i in range(blockCount)]
    result = result.reindex(random.permutation(result.index))
        
    conditionGroups=[]
    conditionCombination = list(itertools.product(*[[(k,v) for v in conditions[k]] for k in conditions]))
    for k in conditionCombination:    
        queryCmd = ' & '.join([i[0]+'=='+str(i[1]) for i in k])
        conditionGroups.append(result.query(queryCmd))
    
    n = len(result)//len(conditionCombination)//blockCount
    for idx,b in enumerate(blocks):
        for c in conditionGroups:
            b.append(c[n*idx:n*(idx+1)])
    
    for i,b in enumerate(blocks):
        b = pd.concat(b)
        blocks[i] = b.reindex(random.permutation(b.index))
    return blocks
  
def factory(data,idx,conditions=None):
    stimli =[]
    for wordID,i in enumerate(idx):
        now = data.ix[i]
        for Target,TargetAcc in ((now.word,1),(now.pseudo_word,0)):
            for PrimePos in (0,1):
                for Prime,PrimeAcc in ((Target[PrimePos],1),(now.match[PrimePos][TargetAcc],0)):    
                    stimli.append({'WordID':wordID,'Prime':Prime,'Target':Target,
                     'PrimeAcc':PrimeAcc,'TargetAcc':TargetAcc,'PrimePos':PrimePos,
                     'w_freq':now.w_freq,'c1_freq':now.c1_freq,'c2_freq':now.c2_freq,'c1_strokeN':now.c1_strokeN,'c2_strokeN':now.c2_strokeN})

    table = pd.DataFrame(stimli,columns=['WordID','Prime','Target','PrimeAcc','TargetAcc','PrimePos','w_freq','c1_freq','c2_freq','c1_strokeN','c2_strokeN'])
    
    part1 = table[:len(table)//2]
    part2 = table[len(table)//2:]
    samplePosL = part1[part1.PrimePos==0]
    samplePosR = part2[part2.PrimePos==1]
    comb = samplePosL.append(samplePosR)

    if conditions == None:
        result = comb.reindex(random.permutation(comb.index))
    else:
        result = randomInBlock(comb,conditions,2)
    return result

tdata = rawdata[(rawdata.w_freq<30000) & (rawdata.c1_freq>100000) & (rawdata.c1_freq>100000) & (rawdata.c1_strokeN.isin(range(7,14))) & (rawdata.c2_strokeN.isin(range(7,14)))]
tdata.index = list(range(len(tdata)))

practice_data=tdata[:4]
experiment_data=tdata[4:]
sampleNum = 40
sampleIdx = random.choice(list(range(4,len(experiment_data))),sampleNum)

practiceTable = factory(practice_data,[0,1,2,3])
practiceTable.to_csv('d:\\stims_block0.csv')

blockTables = factory(experiment_data,sampleIdx,{'PrimeAcc':[0,1],'TargetAcc':[0,1],'PrimePos':[0,1]})
for i,blockTable in enumerate(blockTables):
    blockTable.to_csv('d:\\stims_block'+str(i+1)+'.csv')

# %%
blockTables[0]
# Out:
#      WordID Prime Target  PrimeAcc  TargetAcc  PrimePos  w_freq  c1_freq  \
# 275      34     熙     清楚         0          1         1    5009   161166
# 311      38     喜     曾雄         0          0         1    5251   287181
# 186      23     能     性能         1          1         1    6970   366727
# 226      28     数     指数         1          1         1    4810   208688
# 141      17     验     深做         0          0         0    4976   106711
# 178      22     数     指数         1          1         1    4810   208688
# 243      30     并     修建         0          1         1    7610   110340
# 206      25     样     村样         1          0         1   11791   325606
# 49        6     埃     率领         0          1         0   10914   112961
# 294      36     括     副括         1          0         1    7332   117349
# 56        7     教     教堂         1          1         0   18137   423598
# 283      35     兼     明显         0          1         1   14435   288958
# 45        5     简     朝过         0          0         0   14841   130333
# 92       11     神     神控         1          0         0    8388   283855
# 211      26     情     据说         0          1         1    5223   158496
# 101      12     校     产密         0          0         0   20007   288958
# 319      39     种     尼关         0          0         1    3931   399311
# 24        3     委     委员         1          1         0   20149   177545
# 287      35     附     团盛         0          0         1   14435   288958
# 156      19     动     动青         1          0         0   18846   417112
# 314      39     现     体现         1          1         1    3931   399311
# 4         0     相     相痛         1          0         0    9546   227407
# 166      20     奥     族奥         1          0         1   10914   112961
# 259      32     员     改进         0          1         1    6055   229853
# 41        5     移     福建         0          1         0   14841   130333
# 97       12     命     明朝         0          1         0   20007   288958
# 37        4     林     欧温         0          0         0    5582   184916
# 222      27     蒂     变蒂         1          0         1   10955   283855
# 29        3     选     致英         0          0         0   20149   177545
# 140      17     深     深做         1          0         0    4976   106711
# ..      ...   ...    ...       ...        ...       ...     ...      ...
# 299      37     者     知县         0          1         1    9027   135463
# 36        4     欧     欧温         1          0         0    5582   184916
# 290      36     金     黄金         1          1         1    7332   117349
# 255      31     去     项助         0          0         1    9116   151847
# 8         1     高     高校         1          1         0    4180   460377
# 32        4     图     图像         1          1         0    5582   184916
# 72        9     空     空间         1          1         0   23021   191544
# 1         0     站     接触         0          1         0    9546   227407
# 9         1     度     高校         0          1         0    4180   460377
# 125      15     县     使还         0          0         0   10834   303582
# 81       10     播     解除         0          1         0    4068   155812
# 286      35     盛     团盛         1          0         1   14435   288958
# 44        5     朝     朝过         1          0         0   14841   130333
# 0         0     接     接触         1          1         0    9546   227407
# 191      23     金     建说         0          0         1    6970   366727
# 218      27     输     运输         1          1         1   10955   283855
# 238      29     货     未货         1          0         1    3641   103916
# 270      33     暗     网暗         1          0         1    3766   155968
# 61        7     选     常响         0          0         0   18137   423598
# 198      24     诸     英诸         1          0         1   30194   400224
# 210      26     说     据说         1          1         1    5223   158496
# 93       11     官     神控         0          0         0    8388   283855
# 76        9     说     说南         1          0         0   23021   191544
# 129      16     这     经常         0          1         0   21352   460672
# 303      37     语     查府         0          0         1    9027   135463
# 266      33     款     条款         1          1         1    3766   155968
# 175      21     药     林汗         0          0         1    4344   303582
# 148      18     陆     陆乾         1          0         0    4953   206991
# 40        5     福     福建         1          1         0   14841   130333
# 73        9     波     空间         0          1         0   23021   191544
#
#      c2_freq  c1_strokeN  c2_strokeN
# 275    25198          11          13
# 311    69505          11          13
# 186   400224           8          10
# 226   345136           9          13
# 141    97215          12          12
# 178   345136           9          13
# 243   417112           9           8
# 206   187503           9           9
# 49    177950          11          11
# 294   270345          11           8
# 56     92763          11          11
# 283    75231           8           9
# 45    417112          13           8
# 92    108670           7          11
# 211   226495          11           9
# 101   190068           8          12
# 319   460808           7           8
# 24    425520           8           7
# 287    75231           8           9
# 156   164172           8          10
# 314   460808           7           8
# 4      21131          11          13
# 166   177950          11          11
# 259   415414           7           7
# 41    417112          13           8
# 97    190068           8          12
# 37     86145           8          13
# 222    48852           7          13
# 29    425520           8           7
# 140    97215          12          12
# ..       ...         ...         ...
# 299   335985           8           7
# 36     86145           8          13
# 290   270345          11           8
# 255    97389           9           7
# 8     188153          10          10
# 32     86145           8          13
# 72    412657           8           7
# 1      21131          11          13
# 9     188153          10          10
# 125   158004           9           9
# 81    117837          13           9
# 286    75231           8           9
# 44    417112          13           8
# 0      21131          11          13
# 191   400224           8          10
# 218    48852           7          13
# 238    63996           7           8
# 270    43036           7          12
# 61     92763          11          11
# 198    40809          10          11
# 210   226495          11           9
# 93    108670           7          11
# 76    412657           8           7
# 129   257427           8          11
# 303   335985           8           7
# 266    43036           7          12
# 175    32737           9           7
# 148    19612           9          13
# 40    417112          13           8
# 73    412657           8           7
#
# [80 rows x 11 columns]

# %%
def factory(data,idx):
    stimli =[]
    for wordID,i in enumerate(idx):
        now = data.ix[i]
        for Target,TargetAcc in ((now.word,1),(now.pseudo_word,0)):
            for PrimePos in (0,1):
                for Prime,PrimeAcc in ((Target[PrimePos],1),(now.match[PrimePos][TargetAcc],0)):    
                    stimli.append({'WordID':wordID,'Prime':Prime,'Target':Target,
                     'PrimeAcc':PrimeAcc,'TargetAcc':TargetAcc,'PrimePos':PrimePos,
                     'w_freq':now.w_freq,'c1_freq':now.c1_freq,'c2_freq':now.c2_freq,'c1_strokeN':now.c1_strokeN,'c2_strokeN':now.c2_strokeN})

    table = pd.DataFrame(stimli,columns=['WordID','Prime','Target','PrimeAcc','TargetAcc','PrimePos','w_freq','c1_freq','c2_freq','c1_strokeN','c2_strokeN'])
    
    part1 = table[:len(table)//2]
    part2 = table[len(table)//2:]
    samplePosL = part1[part1.PrimePos==0]
    samplePosR = part2[part2.PrimePos==1]
    result = samplePosL.append(samplePosR)
    result = result.reindex(random.permutation(result.index))
    result.index = list(range(len(result)))
    return result

practice_data=rawdata[:4]
experiment_data=rawdata[4:]
sampleNum = 32
sampleIdx = random.choice(list(range(4,len(experiment_data))),sampleNum)

practiceTable = factory(practice_data,[0,1,2,3])
stimliTable = factory(experiment_data,sampleIdx)
practiceTable.to_csv('d:\\stims_block0.csv')
stimliTable.to_csv('d:\\stims_block1.csv')
