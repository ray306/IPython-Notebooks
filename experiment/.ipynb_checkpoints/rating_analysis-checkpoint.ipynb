# %%
# %pylab inline
path4 = 'D:\\nlp\\zh\\stimuli\\bigram2n_rating\\zy.xlsx'
rating1 = (pd.ExcelFile(path4).parse('test')).sort_index(by='word')
path4 = 'D:\\nlp\\zh\\stimuli\\bigram2n_rating\\whn.xlsx'
rating2 = (pd.ExcelFile(path4).parse('test')).sort_index(by='word')

# %%
# %pylab inline
import pandas as pd
path = 'D:\\nlp\\zh\\stimuli\\bigram2n_rating\\'
rating1 = (pd.ExcelFile(path+'zy.xlsx').parse('test')).sort_index(by='word')
rating=df.reindex(random.permutation(df.index))
rating2 = (pd.ExcelFile(path+'whn.xlsx').parse('test')).sort_index(by='word')
rating1.index = list(range(len(rating1)))
rating2.index = list(range(len(rating2)))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rating = rating1.copy(deep=True)
rating['wholeness'] = (rating1['wholeness']+rating2['wholeness'])/2
rating['frequency'] = (rating1['frequency']+rating2['frequency'])/2

# %%
rating
# Out:
#      word  frequency  wholeness  transparency1  transparency2
# 0    专家学者        3.0        3.5              5              4
# 1    世界冠军        2.0        5.0              2              4
# 2    世界和平        2.5        4.5              2              2
# 3    世界地图        3.0        3.5              2              4
# 4    世界纪录        3.0        3.5              4              4
# 5    业余时间        2.5        4.0              3              2
# 6    东欧国家        1.0        4.0              5              2
# 7    两国关系        1.5        2.5              2              2
# 8    中华民族        3.0        3.0              5              5
# 9    中国联通        2.5        4.0              3              2
# 10   临床试验        2.5        5.0              4              2
# 11   主治医师        1.5        4.0              4              3
# 12   主治医生        2.5        4.0              3              2
# 13   丽江古城        1.0        4.0              3              2
# 14   书面材料        2.0        4.0              3              1
# 15   书面许可        2.0        3.0              3              3
# 16   交响乐团        2.5        4.5              4              3
# 17   交通事故        4.5        5.5              5              5
# 18   交通安全        2.5        4.0              2              2
# 19   交通枢纽        2.0        4.0              3              3
# 20   交通规则        3.5        3.5              2              2
# 21   交通运输        2.0        4.5              2              2
# 22   产品质量        2.5        3.5              3              3
# 23   优惠待遇        1.5        2.5              2              2
# 24   传输距离        1.0        3.0              2              2
# 25   体育场馆        2.0        3.0              3              5
# 26   兄弟姐妹        6.0        6.0              4              4
# 27   免费软件        2.5        2.5              3              2
# 28   公安机关        3.5        5.5              4              3
# 29   养老保险        2.5        4.0              4              2
# ..    ...        ...        ...            ...            ...
# 332  身体素质        2.5        3.5              2              2
# 333  身家性命        2.5        4.5              6              4
# 334  远东地区        1.0        4.0              5              2
# 335  远程监控        1.0        4.5              5              5
# 336  违法活动        2.5        4.0              4              2
# 337  连锁反应        2.0        4.0              5              3
# 338  通讯系统        1.5        3.0              2              2
# 339  逻辑思维        3.5        5.0              5              3
# 340  邮政编码        3.5        5.0              4              4
# 341  金属元素        1.0        3.0              2              3
# 342  钢筋水泥        2.0        4.0              4              4
# 343  银行利率        3.0        5.5              2              3
# 344  银行帐号        5.0        5.0              2              4
# 345  阶级斗争        2.5        5.5              5              4
# 346  雄心壮志        2.5        5.0              5              5
# 347  集体利益        2.5        4.0              2              2
# 348  革命运动        1.5        3.5              3              2
# 349  音乐学院        1.5        4.0              2              2
# 350  音响设备        1.5        4.0              3              2
# 351  音频文件        2.0        3.5              3              3
# 352  音频设备        1.0        3.0              2              2
# 353  食物中毒        3.0        4.0              3              5
# 354  高层建筑        1.5        3.5              3              3
# 355  高清电视        1.5        3.5              3              5
# 356  鸦片战争        1.5        4.5              4              2
# 357  黄道吉日        2.0        5.0              3              4
# 358  黄金市场        1.5        2.5              2              2
# 359  黄金时间        2.0        3.5              2              2
# 360  黄金饰品        1.5        3.5              3              3
# 361  黑客帝国        2.0        5.5              3              3
#
# [362 rows x 5 columns]

# %%
rating[rating['frequency']>1].to_csv(path+'result.csv',index=None)

# %%
rating[rating['frequency']<=1].to_csv(path+'re.csv',index=None)

# %%
rating.sort_index(by='wholeness',ascending=False)
# Out:
#      word  frequency  wholeness  transparency1  transparency2
# 31   军事基地        2.0        6.0              4              5
# 316  计划生育        2.0        6.0              3              4
# 26   兄弟姐妹        6.0        6.0              4              4
# 324  财政赤字        3.5        6.0              4              6
# 233  百科全书        3.0        6.0              5              5
# 361  黑客帝国        2.0        5.5              3              3
# 36   化学反应        2.0        5.5              4              4
# 253  科学技术        5.0        5.5              3              3
# 345  阶级斗争        2.5        5.5              5              4
# 343  银行利率        3.0        5.5              2              3
# 28   公安机关        3.5        5.5              4              3
# 180  河东狮吼        1.5        5.5              4              5
# 259  稀世珍宝        2.5        5.5              4              5
# 58   国会议员        2.5        5.5              4              4
# 188  流水作业        2.5        5.5              2              2
# 17   交通事故        4.5        5.5              5              5
# 163  标点符号        4.0        5.5              5              4
# 127  心肝宝贝        2.0        5.5              4              4
# 198  温室气体        2.5        5.5              4              2
# 100  宗教信仰        2.0        5.5              3              5
# 285  网络游戏        4.0        5.5              3              5
# 211  珍珠奶茶        4.5        5.5              2              5
# 257  科研成果        3.0        5.0              4              4
# 302  自动扶梯        2.5        5.0              3              4
# 315  观音菩萨        3.0        5.0              4              4
# 307  花样滑冰        2.0        5.0              4              4
# 296  股票价格        4.5        5.0              4              2
# 280  维基百科        3.5        5.0              5              5
# 294  联系方式        5.5        5.0              3              4
# 281  综艺节目        4.0        5.0              5              2
# ..    ...        ...        ...            ...            ...
# 265  童话故事        3.5        3.0              5              2
# 267  纪念活动        2.0        3.0              3              2
# 112  家庭生活        2.5        3.0              3              2
# 27   免费软件        2.5        2.5              3              2
# 158  普通民众        2.5        2.5              2              3
# 7    两国关系        1.5        2.5              2              2
# 358  黄金市场        1.5        2.5              2              2
# 146  文档资料        2.0        2.5              4              3
# 274  经济情况        2.0        2.5              2              2
# 23   优惠待遇        1.5        2.5              2              2
# 282  绿色植物        1.5        2.5              3              3
# 277  经济活动        2.5        2.5              4              3
# 97   宇宙空间        1.5        2.5              3              3
# 203  物理性质        2.0        2.5              2              2
# 331  身体检查        2.0        2.5              2              2
# 64   国家政权        1.5        2.5              3              5
# 122  形象思维        1.5        2.5              3              2
# 278  经验交流        2.0        2.5              2              2
# 173  民族政策        1.0        2.5              2              2
# 174  民族矛盾        1.0        2.5              2              2
# 215  生活待遇        1.5        2.0              2              2
# 309  英雄形象        1.5        2.0              2              3
# 148  新闻单位        1.0        2.0              3              3
# 80   城市绿化        1.5        2.0              2              2
# 71   国际和平        2.0        2.0              2              2
# 32   创业投资        2.5        2.0              2              2
# 61   国家公园        1.0        2.0              2              2
# 212  生产秩序        1.0        1.5              2              2
# 164  校园网络        1.5        1.5              2              3
# 152  旅游事业        1.0        1.5              2              2
#
# [362 rows x 5 columns]

# %%
'相关性评分'
import scipy.stats
col = 'wholeness'
numpy.corrcoef(rating1[col], rating2[col])[0, 1]
print(scipy.stats.spearmanr(rating1[col], rating2[col]))

# %%
ind='transparency1'
plt.plot((rawdata.sort_index(by=ind))[ind])
