# %%
import pandas as pd
import random
# %pylab inline

rawdata = pd.read_csv('D:/nlp/zh/SogouR.txt', sep='\t',encoding='gbk')
rawdata.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#     工艺-供应  392
# 0  政法-研究生    6
# 1    2-住址    3
# 2   重复-设计   15
# 3  漳州-南山寺    8
# 4  影响-形体美   30

# %%
high = rawdata[rawdata['392']>2**12]

# %%
high = high.sort(['freq'], ascending=False)
high
# Out:
#          word1     freq word2
# 13210860    在线  5321995    时间
# 10423367    访问  5046776    次数
# 14871226    日志  4781012    总数
# 9413539     建立  4766301    时间
# 7641494     评论  4754897    数量
# 5140943     进行  4626879    管理
# 2436588     暂无  4605812    内容
# 6429048     栏目  4588733    暂无
# 14608355    分钟  4547657    日志
# 8073016   基本信息  4522783   用户名
# 17595151    博客  4502374  基本信息
# 13911127    等级  4424682  初来乍到
# 16143009  初来乍到  4411671    威望
# 12643476    等待  2150595    用户
# 15840427    内容  2150520    等待
# 13285144    最新  1410893    日志
# 18387430    支持  1271826    支持
# 17508062    模式   945575    普通
# 6286020     普通   945272    列表
# 8018587     状态   938852    离线
# 10041723    最后   917243    登录
# 9240809     阅读   867171    权限
# 10673648    博客   826407    信息
# 2233289     最新   779835    博客
# 14944021    浏览   733508    模式
# 6117339     最新   727021    评论
# 16429918    小时   674023  注册时间
# 2112400   顶顶顶顶   660896  顶顶顶顶
# 17595159    立场   613266    无关
# 9390578     联系   548258    我们
# ...

# %%
high.word2 = high.word1.apply(lambda x: x.split('-')[1])
high.word1 = high.word1.apply(lambda x: x.split('-')[0])
# Out:
# h:\Anaconda3\lib\site-packages\pandas\core\generic.py:1858: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self[name] = value

# %%
high[high.freq]
# Out:
# 367       [中文, 片名]
# 2173      [感谢, 所有]
# 2682      [种子, 均为]
# 3024      [本类, 一个]
# 3643    [条款, 网站简介]
# Name: word1, dtype: object

# %%
plot(sorted(rawdata[rawdata['392']>2**10]['392'].apply(lambda x: math.log(x,2))))
